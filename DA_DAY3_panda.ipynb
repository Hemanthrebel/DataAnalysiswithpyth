# %% [markdown]
# panda:
# - used for data manipulation(data cleaning,organizing data)
# -creates dataframes from excel,csv,txt,dbs
# -dataframe(rows and coloums readable by python)
# -data cleaning by dropping or replacing with mean
# -visualize the data

# %%
import pandas as pd

# %%
names=["ironman","hulk","capitanamerica","spiderman","thor"]
index=[40,42,42,43,45]
ser1=pd.Series(names,index)

# %%
print(ser1)
# Out:
# 40           ironman
# 42              hulk
# 42    capitanamerica
# 43         spiderman
# 45              thor
# dtype: object

# %% [markdown]
# importing files
# - for csv and txt:read_csv('file path)
# -for excel:read_excel('file path)

# %%
df=pd.read_csv("/content/mcu_box_office.csv")

# %%
df.head()
# Out:
#                                 Movie Release Date  Domestic Box Office  \
# 0                            Iron Man     5/2/2008            318604126
# 1                 The Incredible Hulk    6/13/2008            134806913
# 2                          Iron Man 2     5/7/2010            312433331
# 3                                Thor     5/6/2011            181030624
# 4  Captain America: The First Avenger    7/22/2011            176654505
#
#    Inflation Adjusted Domestic  International Box Office  \
# 0                    467231126                 266567421
# 1                    197704288                 130766946
# 2                    416973763                 308723058
# 3                    240384926                 268295994
# 4                    234574020                 193915271
#
#    World Wide Box Office  Opening Weekend     Budget  IMDb Score  Meta Score  \
# 0              585171547        102118668  186000000         7.9          79
# ...

# %%
df.tail()
# Out:
#                                 Movie Release Date  Domestic Box Office  \
# 28             Thor: Love and Thunder     7/8/2022            343256830
# 29     Black Panther: Wakanda Forever   11/11/2022            453829060
# 30  Ant-Man and the Wasp: Quantumania    2/17/2023            214506909
# 31     Guardians of the Galaxy Vol. 3     5/5/2023            358995815
# 32                        The Marvels   11/10/2023             84500223
#
#     Inflation Adjusted Domestic  International Box Office  \
# 28                    343256830                 417671251
# 29                    453829060                 400156486
# 30                    214506909                 249128394
# 31                    358995815                 486472929
# 32                     84500223                 115206027
#
#     World Wide Box Office  Opening Weekend     Budget  IMDb Score  Meta Score  \
# 28              760928081        144165107  250000000         6.2          57
# ...

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dft=pd.read_excel("/content/diabetes.xlsx")

# %%
dft.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
print(df.shape)#get the number of rows and coloums
print(df.shape[0])#get the number of rows only
print(df.shape[1])#get the number of coloums only
# Out:
# (33, 15)
# 33
# 15

# %% [markdown]
# Accessing data
# - loc-accepts column names and index
# -iloc-accepts only index

# %%
print(dft[2:5]) #to access rows
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
print(dft.loc[3:5],"names") #to accessed specified column
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative names

# %%
print(dft.iloc[3:5],"names") #to accessed specified index
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive names

# %%
print(dft.iloc[2:5,:3]) #iloc[row range,column range]=>index
# Out:
#    preg  plas  pres
# 2     8   183    64
# 3     1    89    66
# 4     0   137    40

# %%
df=pd.read_csv("/content/grades_withnulls (1).csv")

# %%
df.isnull().head()
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False

# %%
df.isnull().sum() #to view how many null we have per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
df.isnull().sum().sum() #to view total null
# Out:
# 4

# %%
df.dropna() #dropping all the rows with nulls
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df=df.fillna(5)
df
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# cleaning the mean

# %%
m=df["SEM3"].mean()
print(m)
# Out:
# 8.858823529411765

# %%
df=df.fillna(m)
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dropped=df.drop_duplicates()
print(dropped)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
df.rename(columns={"Grade":"GPA"}) #df.rename(columns=(old:new))
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   5.0   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   5.0   9.1   9.9  A+       1
# 9   Rajini        M   5.0   9.1   9.3   A       0
# 10   Kiran        V   5.0   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
df.rename(columns={"Grade":"GPA"},inplace=True) #df.rename(columns=(old:new))
df.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   5.0   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
df['Avg_score']=(df['SEM1']+df['SEM2']+df['SEM3'])/3  #df['newcol]=values

# %%
df.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 GPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1        9.9
# 1  Rajesh        M   8.9   9.1   9.3   A       1        9.1
# 2  Kissan        V   9.9   9.8  10.0   A       0        9.9
# 3    Mary        N   7.7   8.0   5.0   B       0        6.9
# 4    Jeen        K   9.8   9.1   9.9  A+       1        9.6

# %%
df[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='SEM1',y='Names',data=df)

# %%
sns.relplot( data=df,x="SEM2",y="SEM1",col="Placed")

# %%
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# load
# create the relplot with the age =x class as columns

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df["index"]=range(1,769)
df.head()
sns.relplot(x="age",y="index",data=df,col="class")

# %% [markdown]
# inbuild data types
# - tips
# - dowjonels
# - fmri
# - dots
# - healthtxt
# - to load dataset use
# - load_dataset("datasetname")
# - hue=different color for differnet categary
# - style=different marker for different categary
# - color palette
# - pastel
# - bright
# - dark
# - muted
# - color bright
# - deep

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips,y="tip",x="total_bill",hue="day",style="time",palette="pastel",kind="line")

# %%
sns.catplot(data=tips,x="day",y="total_bill",kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,x="total_bill",y="day")

# %%
dowjones=sns.load_dataset("dowjones")
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dowjones,y="Price",x="Date",kind="line")

# %%
fmri=sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.catplot(data=fmri,x="region",y="timepoint")

# %%
dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp=sns.load_dataset("healthexp")
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %% [markdown]
# linear fit
# - plotting data set
# -fitting the data line
# -prediction

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %% [markdown]
# web scrapping:
# loading the data from the webserver
# - unstructured in html
# -convertable into spreadsheets/db
# -major websites have their apis for web scrapping
# -purpase of the scrapping
# -extract all the data on particular
# -specifies data that a user wants
# -process
# -url->
# -html code->
# -elements(css/js)
# -scrapes the requrired format(csv/xlsx/json)
# -application
# -email marketing
# -sentiment analysis
# -news monitoring
# -market research
# -price monitoring
